# %%
import nltk
nltk.download('stopwords')

import numpy as np
import pandas as pd
import os
import re
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from bs4 import BeautifulSoup 
from tensorflow.keras.preprocessing.text import Tokenizer 
from tensorflow.keras.preprocessing.sequence import pad_sequences
import urllib.request
import warnings
warnings.filterwarnings("ignore", category=UserWarning, module='bs4')

print('=3')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# =3

# %%
data = pd.read_csv('/content/drive/MyDrive/AIFFEL/EX/E12/news_summarization/data/news_summary_more.csv')
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 98401

# %%
# 샘플 5개만 출력
data.head()
# Out:
#                                            headlines  \
# 0  upGrad learner switches to career in ML & Al w...
# 1  Delhi techie wins free food from Swiggy for on...
# 2  New Zealand end Rohit Sharma-led India's 12-ma...
# 3  Aegon life iTerm insurance plan helps customer...
# 4  Have known Hirani for yrs, what if MeToo claim...
#
#                                                 text
# 0  Saurav Kant, an alumnus of upGrad and IIIT-B's...
# 1  Kunal Shah's credit card bill payment platform...
# 2  New Zealand defeated India by 8 wickets in the...
# 3  With Aegon Life iTerm Insurance plan, customer...
# 4  Speaking about the sexual harassment allegatio...

# %%
# 데이터의 중복 샘플 유무 확인
print('Text 열에서 중복을 배제한 유일한 샘플의 수 :', data['text'].nunique())
print('Headlines 열에서 중복을 배제한 유일한 샘플의 수 :', data['headlines'].nunique())
# Out:
# Text 열에서 중복을 배제한 유일한 샘플의 수 : 98360
# Headlines 열에서 중복을 배제한 유일한 샘플의 수 : 98280

# %%
# 데이터프레임의 drop_duplicates()를 사용하여 중복 샘플을 제거
# inplace=True 를 설정하면 DataFrame 타입 값을 return 하지 않고 data 내부를 직접적으로 바꿉니다
data.drop_duplicates(subset = ['text'], inplace=True)
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 98360

# %%
# Null 값 확인
print(data.isnull().sum())
# Out:
# headlines    0
# text         0
# dtype: int64

# %%
# 텍스트 정규화
contractions = {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",
                           "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",
                           "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",
                           "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",
                           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",
                           "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",
                           "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",
                           "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",
                           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",
                           "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",
                           "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",
                           "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",
                           "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",
                           "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",
                           "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",
                           "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",
                           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",
                           "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",
                           "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",
                           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",
                           "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                           "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",
                           "you're": "you are", "you've": "you have"}

print("정규화 사전의 수: ", len(contractions))
# Out:
# 정규화 사전의 수:  120

# %%
# NLTK에서 제공하는 불용어 리스트를 참조
print('불용어 개수 :', len(stopwords.words('english') ))
print(stopwords.words('english'))
# Out:
# 불용어 개수 : 179
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %%
# 데이터 전처리 함수
def preprocess_sentence(sentence, remove_stopwords=True):
    sentence = sentence.lower() # 텍스트 소문자화
    sentence = BeautifulSoup(sentence, "lxml").text # <br />, <a href = ...> 등의 html 태그 제거
    sentence = re.sub(r'\([^)]*\)', '', sentence) # 괄호로 닫힌 문자열 (...) 제거 Ex) my husband (and myself!) for => my husband for
    sentence = re.sub('"','', sentence) # 쌍따옴표 " 제거
    sentence = ' '.join([contractions[t] if t in contractions else t for t in sentence.split(" ")]) # 약어 정규화
    sentence = re.sub(r"'s\b","", sentence) # 소유격 제거. Ex) roland's -> roland
    sentence = re.sub("[^a-zA-Z]", " ", sentence) # 영어 외 문자(숫자, 특수문자 등) 공백으로 변환
    sentence = re.sub('[m]{2,}', 'mm', sentence) # m이 3개 이상이면 2개로 변경. Ex) ummmmmmm yeah -> umm yeah
    
    # 불용어 제거 (Text)
    if remove_stopwords:
        tokens = ' '.join(word for word in sentence.split() if not word in stopwords.words('english') if len(word) > 1)
    # 불용어 미제거 (headlines)
    else:
        tokens = ' '.join(word for word in sentence.split() if len(word) > 1)
    return tokens
print('=3')
# Out:
# =3

# %%
# 임의의 text와 headlines 를 만들어 함수를 호출
temp_text = 'Everything I bought was great, infact I ordered twice and the third ordered was<br />for my mother and father.'
temp_headlines  = 'Great way to start (or finish) the day!!!'

print("text: ", preprocess_sentence(temp_text))
print("headlines :", preprocess_sentence(temp_headlines , False))  # 불용어를 제거하지 않습니다.
# Out:
# text:  everything bought great infact ordered twice third ordered wasfor mother father
# headlines : great way to start the day

# %%
clean_text = []
# 전체 Text 데이터에 대한 전처리 : 10분 이상 시간이 걸릴 수 있습니다. 
for s in data['text']:
    clean_text.append(preprocess_sentence(s))

# 전처리 후 출력
print("Text 전처리 후 결과: ", clean_text[:5])
# Out:
# Text 전처리 후 결과:  ['saurav kant alumnus upgrad iiit pg program machine learning artificial intelligence sr systems engineer infosys almost years work experience program upgrad degree career support helped transition data scientist tech mahindra salary hike upgrad online power learning powered lakh careers', 'kunal shah credit card bill payment platform cred gave users chance win free food swiggy one year pranav kaushik delhi techie bagged reward spending cred coins users get one cred coin per rupee bill paid used avail rewards brands like ixigo bookmyshow ubereats cult fit', 'new zealand defeated india wickets fourth odi hamilton thursday win first match five match odi series india lost international match rohit sharma captaincy consecutive victories dating back march match witnessed india getting seventh lowest total odi cricket history', 'aegon life iterm insurance plan customers enjoy tax benefits premiums paid save taxes plan provides life cover age years also customers options insure critical illnesses disability accidental death benefit rider life cover age years', 'speaking sexual harassment allegations rajkumar hirani sonam kapoor said known hirani many years true metoo movement get derailed metoo movement always believe woman case need reserve judgment added hirani accused assistant worked sanju']

# %%
clean_headlines = []
# 전체 headlines 데이터에 대한 전처리 : 5분 이상 시간이 걸릴 수 있습니다. 
for s in data['headlines']:
    clean_headlines.append(preprocess_sentence(s, False))

print("headlines 전처리 후 결과: ", clean_headlines[:5])
# Out:
# headlines 전처리 후 결과:  ['upgrad learner switches to career in ml al with salary hike', 'delhi techie wins free food from swiggy for one year on cred', 'new zealand end rohit sharma led india match winning streak', 'aegon life iterm insurance plan helps customers save tax', 'have known hirani for yrs what if metoo claims are not true sonam']

# %%
# 빈(empty) 샘플이 생겼는지 확인
data['text'] = clean_text
data['headlines'] = clean_headlines

# 빈 값을 Null 값으로 변환
data.replace('', np.nan, inplace=True)
print('=3')
# Out:
# =3

# %%
# Null 값 확인
data.isnull().sum()
# Out:
# headlines    0
# text         0
# dtype: int64

# %%
# 길이 분포 출력
import matplotlib.pyplot as plt

text_len = [len(s.split()) for s in data['text']]
headlines_len = [len(s.split()) for s in data['headlines']]

print('텍스트의 최소 길이 : {}'.format(np.min(text_len)))
print('텍스트의 최대 길이 : {}'.format(np.max(text_len)))
print('텍스트의 평균 길이 : {}'.format(np.mean(text_len)))
print('요약의 최소 길이 : {}'.format(np.min(headlines_len)))
print('요약의 최대 길이 : {}'.format(np.max(headlines_len)))
print('요약의 평균 길이 : {}'.format(np.mean(headlines_len)))

plt.subplot(1,2,1)
plt.boxplot(text_len)
plt.title('text')
plt.subplot(1,2,2)
plt.boxplot(headlines_len)
plt.title('headlines')
plt.tight_layout()
plt.show()

plt.title('text')
plt.hist(text_len, bins = 40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()

plt.title('headlines')
plt.hist(headlines_len, bins = 40)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 텍스트의 최소 길이 : 1
# 텍스트의 최대 길이 : 60
# 텍스트의 평균 길이 : 35.09968483123221
# 요약의 최소 길이 : 1
# 요약의 최대 길이 : 16
# 요약의 평균 길이 : 9.299532330215534

# %%
# text의 최대 길이와 headlines의 적절한 최대 길이를 임의로 정함
text_max_len = 50
headlines_max_len = 15
print('=3')
# Out:
# =3

# %%
# 훈련 데이터와 샘플의 길이를 입력하면, 데이터의 몇 %가 해당하는지 계산하는 함수
def below_threshold_len(max_len, nested_list):
  cnt = 0
  for s in nested_list:
    if(len(s.split()) <= max_len):
        cnt = cnt + 1
  print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (cnt / len(nested_list))))
print('=3')
# Out:
# =3

# %%
below_threshold_len(text_max_len, data['text'])
below_threshold_len(headlines_max_len,  data['headlines'])
# Out:
# 전체 샘플 중 길이가 50 이하인 샘플의 비율: 0.9998576657177715
# 전체 샘플 중 길이가 15 이하인 샘플의 비율: 0.9999694997966653

# %%
# 정해진 길이보다 길면 제외하는 방법으로 데이터를 정제
data = data[data['text'].apply(lambda x: len(x.split()) <= text_max_len)]
data = data[data['headlines'].apply(lambda x: len(x.split()) <= headlines_max_len)]
print('전체 샘플수 :', (len(data)))
# Out:
# 전체 샘플수 : 98343

# %%
# 요약 데이터에는 시작 토큰과 종료 토큰을 추가한다.
data['decoder_input'] = data['headlines'].apply(lambda x : 'sostoken '+ x)
data['decoder_target'] = data['headlines'].apply(lambda x : x + ' eostoken')
data.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                            headlines  \
# 0  upgrad learner switches to career in ml al wit...
# 1  delhi techie wins free food from swiggy for on...
# 2  new zealand end rohit sharma led india match w...
# 3  aegon life iterm insurance plan helps customer...
# 4  have known hirani for yrs what if metoo claims...
#
#                                                 text  \
# 0  saurav kant alumnus upgrad iiit pg program mac...
# 1  kunal shah credit card bill payment platform c...
# 2  new zealand defeated india wickets fourth odi ...
# 3  aegon life iterm insurance plan customers enjo...
# 4  speaking sexual harassment allegations rajkuma...
#
#                                        decoder_input  \
# 0  sostoken upgrad learner switches to career in ...
# 1  sostoken delhi techie wins free food from swig...
# 2  sostoken new zealand end rohit sharma led indi...
# 3  sostoken aegon life iterm insurance plan helps...
# 4  sostoken have known hirani for yrs what if met...
#
#                                       decoder_target
# 0  upgrad learner switches to career in ml al wit...
# 1  delhi techie wins free food from swiggy for on...
# 2  new zealand end rohit sharma led india match w...
# 3  aegon life iterm insurance plan helps customer...
# 4  have known hirani for yrs what if metoo claims...

# %%
# 인코더의 입력, 디코더의 입력과 레이블을 각각 다시 Numpy 타입으로 저장
encoder_input = np.array(data['text']) # 인코더의 입력
decoder_input = np.array(data['decoder_input']) # 디코더의 입력
decoder_target = np.array(data['decoder_target']) # 디코더의 레이블
print('=3')
# Out:
# =3

# %%
# encoder_input과 크기와 형태가 같은 순서가 섞인 정수 시퀀스 만들기
indices = np.arange(encoder_input.shape[0])
np.random.shuffle(indices)
print(indices)
# Out:
# [77045 58290 74839 ... 28912 79386 86979]

# %%
# 정수 시퀀스를 이용해 다시 데이터의 샘플 순서를 정의
# 잘 섞이도록
encoder_input = encoder_input[indices]
decoder_input = decoder_input[indices]
decoder_target = decoder_target[indices]
print('=3')
# Out:
# =3

# %%
# 전체 데이터의 크기에서 0.2를 곱해서 테스트 데이터의 크기를 정의
# 8:2의 비율로 훈련 데이터와 테스트 데이터로 분리
n_of_val = int(len(encoder_input)*0.2)
print('테스트 데이터의 수 :', n_of_val)
# Out:
# 테스트 데이터의 수 : 19668

# %%
# 정의한 테스트 데이터의 개수를 이용해 전체 데이터를 양분
encoder_input_train = encoder_input[:-n_of_val]
decoder_input_train = decoder_input[:-n_of_val]
decoder_target_train = decoder_target[:-n_of_val]

encoder_input_test = encoder_input[-n_of_val:]
decoder_input_test = decoder_input[-n_of_val:]
decoder_target_test = decoder_target[-n_of_val:]

print('훈련 데이터의 개수 :', len(encoder_input_train))
print('훈련 레이블의 개수 :', len(decoder_input_train))
print('테스트 데이터의 개수 :', len(encoder_input_test))
print('테스트 레이블의 개수 :', len(decoder_input_test))
# Out:
# 훈련 데이터의 개수 : 78675
# 훈련 레이블의 개수 : 78675
# 테스트 데이터의 개수 : 19668
# 테스트 레이블의 개수 : 19668

# %%
# encoder_input_train에 대한 단어 집합
src_tokenizer = Tokenizer() # 토크나이저 정의
src_tokenizer.fit_on_texts(encoder_input_train) # 입력된 데이터로부터 단어 집합 생성
print('=3')
# Out:
# =3

# %%
threshold = 7
total_cnt = len(src_tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in src_tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :', total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 69692
# 등장 빈도가 6번 이하인 희귀 단어의 수: 47532
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 22160
# 단어 집합에서 희귀 단어의 비율: 68.20295012340011
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 3.485875472936411

# %%
# 등장 빈도가 6회 이하인 단어들은 제거하고 단어 집합 재생성
src_vocab = 20000
src_tokenizer = Tokenizer(num_words=src_vocab) # 단어 집합의 크기를 20000으로 제한
src_tokenizer.fit_on_texts(encoder_input_train) # 단어 집합 재생성
print('=3')
# Out:
# =3

# %%
# 텍스트 시퀀스를 정수 시퀀스로 변환
encoder_input_train = src_tokenizer.texts_to_sequences(encoder_input_train) 
encoder_input_test = src_tokenizer.texts_to_sequences(encoder_input_test)

# 잘 진행되었는지 샘플 출력
print(encoder_input_train[:3])
# Out:
# [[1902, 3498, 1478, 19443, 54, 39, 6198, 2191, 5760, 214, 507, 5309, 10765, 8, 19443, 10766, 29, 132, 5, 2514, 594, 388, 55, 3989, 860, 100, 16, 7780, 3940, 1, 940, 801, 153, 13802, 1118, 1735, 1050, 24, 5417], [50, 2030, 141, 1, 199, 446, 494, 318, 1869, 567, 465, 5704, 499, 494, 6468, 138, 4, 2030, 1, 2587, 333, 138, 2587, 138, 5511, 663, 1161, 366, 64], [3, 13, 11, 1589, 397, 212, 183, 7, 356, 547, 690, 159, 383, 8957, 8405, 1849, 9479, 183, 23, 12550, 1083, 2936, 6713, 4374, 3246, 4106, 6, 405, 712, 1632, 8958, 71, 15998, 1590, 33, 9479]]

# %%
# headlines 데이터에 대해서도 동일한 작업을 수행
tar_tokenizer = Tokenizer()
tar_tokenizer.fit_on_texts(decoder_input_train)
print('=3')
# Out:
# =3

# %%
# 등장 빈도수가 6회 미만인 단어들이 이 데이터에서 얼만큼의 비중을 차지하는지 확인
threshold = 6
total_cnt = len(tar_tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tar_tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :', total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print('단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 %s'%(total_cnt - rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 30037
# 등장 빈도가 5번 이하인 희귀 단어의 수: 19614
# 단어 집합에서 희귀 단어를 제외시킬 경우의 단어 집합의 크기 10423
# 단어 집합에서 희귀 단어의 비율: 65.2994639944069
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 4.6487698895917156

# %%
# 등장 빈도가 5회 이하인 단어들은 제거하고 단어 집합 재생성
tar_vocab = 10000
tar_tokenizer = Tokenizer(num_words=tar_vocab) 
tar_tokenizer.fit_on_texts(decoder_input_train)
tar_tokenizer.fit_on_texts(decoder_target_train)

# 텍스트 시퀀스를 정수 시퀀스로 변환
decoder_input_train = tar_tokenizer.texts_to_sequences(decoder_input_train) 
decoder_target_train = tar_tokenizer.texts_to_sequences(decoder_target_train)
decoder_input_test = tar_tokenizer.texts_to_sequences(decoder_input_test)
decoder_target_test = tar_tokenizer.texts_to_sequences(decoder_target_test)

# 잘 변환되었는지 확인
print('input')
print('input ',decoder_input_train[:5])
print('target')
print('decoder ',decoder_target_train[:5])
# Out:
# input
# input  [[1, 1671, 1650, 4864, 280, 7682, 3100, 4539, 189], [1, 686, 433, 3101, 12, 19, 1033, 418, 5, 70, 85, 1006], [1, 40, 26, 30, 653, 296, 159, 43, 2384, 6, 87, 297, 202], [1, 1142, 9520, 1686, 2583, 6, 4289, 1687, 5], [1, 662, 5888, 175, 511, 4, 4540, 1301, 12, 4865, 702, 2531]]
# target
# decoder  [[1671, 1650, 4864, 280, 7682, 3100, 4539, 189, 2], [686, 433, 3101, 12, 19, 1033, 418, 5, 70, 85, 1006, 2], [40, 26, 30, 653, 296, 159, 43, 2384, 6, 87, 297, 202, 2], [1142, 9520, 1686, 2583, 6, 4289, 1687, 5, 2], [662, 5888, 175, 511, 4, 4540, 1301, 12, 4865, 702, 2531, 2]]

# %%
# 훈련 데이터와 테스트 데이터에 대해서 요약문의 길이가 1인 경우의 인덱스를 각각 drop_train과 drop_test에 라는 변수에 저장
#  샘플들은 모두 삭제
drop_train = [index for index, sentence in enumerate(decoder_input_train) if len(sentence) == 1]
drop_test = [index for index, sentence in enumerate(decoder_input_test) if len(sentence) == 1]

print('삭제할 훈련 데이터의 개수 :', len(drop_train))
print('삭제할 테스트 데이터의 개수 :', len(drop_test))

encoder_input_train = [sentence for index, sentence in enumerate(encoder_input_train) if index not in drop_train]
decoder_input_train = [sentence for index, sentence in enumerate(decoder_input_train) if index not in drop_train]
decoder_target_train = [sentence for index, sentence in enumerate(decoder_target_train) if index not in drop_train]

encoder_input_test = [sentence for index, sentence in enumerate(encoder_input_test) if index not in drop_test]
decoder_input_test = [sentence for index, sentence in enumerate(decoder_input_test) if index not in drop_test]
decoder_target_test = [sentence for index, sentence in enumerate(decoder_target_test) if index not in drop_test]

print('훈련 데이터의 개수 :', len(encoder_input_train))
print('훈련 레이블의 개수 :', len(decoder_input_train))
print('테스트 데이터의 개수 :', len(encoder_input_test))
print('테스트 레이블의 개수 :', len(decoder_input_test))
# Out:
# 삭제할 훈련 데이터의 개수 : 0
# 삭제할 테스트 데이터의 개수 : 0
# 훈련 데이터의 개수 : 78675
# 훈련 레이블의 개수 : 78675
# 테스트 데이터의 개수 : 19668
# 테스트 레이블의 개수 : 19668

# %%
# 최대 길이로 패딩
encoder_input_train = pad_sequences(encoder_input_train, maxlen=text_max_len, padding='post')
encoder_input_test = pad_sequences(encoder_input_test, maxlen=text_max_len, padding='post')
decoder_input_train = pad_sequences(decoder_input_train, maxlen=headlines_max_len, padding='post')
decoder_target_train = pad_sequences(decoder_target_train, maxlen=headlines_max_len, padding='post')
decoder_input_test = pad_sequences(decoder_input_test, maxlen=headlines_max_len, padding='post')
decoder_target_test = pad_sequences(decoder_target_test, maxlen=headlines_max_len, padding='post')
print('=3')
# Out:
# =3

# %%
# 함수형 API를 이용해서 인코더를 설계
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint


# 인코더 설계 시작
embedding_dim = 128
hidden_size = 256

# 인코더
encoder_inputs = Input(shape=(text_max_len,))

# 인코더의 임베딩 층
enc_emb = Embedding(src_vocab, embedding_dim)(encoder_inputs)

# 인코더의 LSTM 1
# encoder_lstm1 = LSTM(hidden_size, return_sequences=True, return_state=True ,dropout = 0.4, recurrent_dropout = 0.4)
encoder_lstm1 = LSTM(hidden_size, return_sequences=True, return_state=True ,dropout = 0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

# 인코더의 LSTM 2
# encoder_lstm2 = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4, recurrent_dropout=0.4)
encoder_lstm2 = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

# 인코더의 LSTM 3
# encoder_lstm3 = LSTM(hidden_size, return_state=True, return_sequences=True, dropout=0.4, recurrent_dropout=0.4)
encoder_lstm3 = LSTM(hidden_size, return_state=True, return_sequences=True, dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)

# %%
# 디코더 설계
decoder_inputs = Input(shape=(None,))

# 디코더의 임베딩 층
dec_emb_layer = Embedding(tar_vocab, embedding_dim)
dec_emb = dec_emb_layer(decoder_inputs)

# 디코더의 LSTM
# decoder_lstm = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4, recurrent_dropout=0.2)
decoder_lstm = LSTM(hidden_size, return_sequences=True, return_state=True, dropout=0.4)
decoder_outputs, _, _ = decoder_lstm(dec_emb, initial_state=[state_h, state_c])

# %%
# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation='softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_outputs) 

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 50)]         0           []
#
#  embedding (Embedding)          (None, 50, 128)      2560000     ['input_1[0][0]']
#
#  lstm (LSTM)                    [(None, 50, 256),    394240      ['embedding[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  input_2 (InputLayer)           [(None, None)]       0           []
#
#  lstm_1 (LSTM)                  [(None, 50, 256),    525312      ['lstm[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  embedding_1 (Embedding)        (None, None, 128)    1280000     ['input_2[0][0]']
#
#  lstm_2 (LSTM)                  [(None, 50, 256),    525312      ['lstm_1[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  lstm_3 (LSTM)                  [(None, None, 256),  394240      ['embedding_1[0][0]',
#                                  (None, 256),                     'lstm_2[0][1]',
#                                  (None, 256)]                     'lstm_2[0][2]']
#
#  dense (Dense)                  (None, None, 10000)  2570000     ['lstm_3[0][0]']
#
# ==================================================================================================
# Total params: 8,249,104
# Trainable params: 8,249,104
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.layers import AdditiveAttention

# 어텐션 층(어텐션 함수)
attn_layer = AdditiveAttention(name='attention_layer')

# 인코더와 디코더의 모든 time step의 hidden state를 어텐션 층에 전달하고 결과를 리턴
attn_out = attn_layer([decoder_outputs, encoder_outputs])


# 어텐션의 결과와 디코더의 hidden state들을 연결
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

# 디코더의 출력층
decoder_softmax_layer = Dense(tar_vocab, activation='softmax')
decoder_softmax_outputs = decoder_softmax_layer(decoder_concat_input)

# 모델 정의
model = Model([encoder_inputs, decoder_inputs], decoder_softmax_outputs)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 50)]         0           []
#
#  embedding (Embedding)          (None, 50, 128)      2560000     ['input_1[0][0]']
#
#  lstm (LSTM)                    [(None, 50, 256),    394240      ['embedding[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  input_2 (InputLayer)           [(None, None)]       0           []
#
#  lstm_1 (LSTM)                  [(None, 50, 256),    525312      ['lstm[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  embedding_1 (Embedding)        (None, None, 128)    1280000     ['input_2[0][0]']
#
#  lstm_2 (LSTM)                  [(None, 50, 256),    525312      ['lstm_1[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  lstm_3 (LSTM)                  [(None, None, 256),  394240      ['embedding_1[0][0]',
#                                  (None, 256),                     'lstm_2[0][1]',
#                                  (None, 256)]                     'lstm_2[0][2]']
#
#  attention_layer (AdditiveAtten  (None, None, 256)   256         ['lstm_3[0][0]',
#  tion)                                                            'lstm_2[0][0]']
#
#  concat_layer (Concatenate)     (None, None, 512)    0           ['lstm_3[0][0]',
#                                                                   'attention_layer[0][0]']
#
#  dense_1 (Dense)                (None, None, 10000)  5130000     ['concat_layer[0][0]']
#
# ==================================================================================================
# Total params: 10,809,360
# Trainable params: 10,809,360
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# 설계한 모델을 가지고 훈련을 진행
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')
es = EarlyStopping(monitor='val_loss', patience=2, verbose=1)
history = model.fit(x=[encoder_input_train, decoder_input_train], y=decoder_target_train, \
          validation_data=([encoder_input_test, decoder_input_test], decoder_target_test), \
          batch_size=128, callbacks=[es], epochs=50)
# Out:
# Epoch 1/50
# 615/615 [==============================] - 40s 54ms/step - loss: 4.4077 - val_loss: 4.0249
# Epoch 2/50
# 615/615 [==============================] - 32s 51ms/step - loss: 3.9209 - val_loss: 3.7530
# Epoch 3/50
# 615/615 [==============================] - 32s 51ms/step - loss: 3.6675 - val_loss: 3.5599
# Epoch 4/50
# 615/615 [==============================] - 32s 51ms/step - loss: 3.4886 - val_loss: 3.4324
# Epoch 5/50
# 615/615 [==============================] - 32s 51ms/step - loss: 3.3466 - val_loss: 3.3394
# Epoch 6/50
# 615/615 [==============================] - 32s 51ms/step - loss: 3.2314 - val_loss: 3.2667
# Epoch 7/50
# 615/615 [==============================] - 32s 52ms/step - loss: 3.1371 - val_loss: 3.2007
# Epoch 8/50
# 615/615 [==============================] - 32s 52ms/step - loss: 3.0501 - val_loss: 3.1556
# Epoch 9/50
# 615/615 [==============================] - 32s 52ms/step - loss: 2.9794 - val_loss: 3.1188
# Epoch 10/50
# 615/615 [==============================] - 32s 51ms/step - loss: 2.9165 - val_loss: 3.0823
# Epoch 11/50
# 615/615 [==============================] - 32s 51ms/step - loss: 2.8606 - val_loss: 3.0556
# Epoch 12/50
# 615/615 [==============================] - 32s 51ms/step - loss: 2.8112 - val_loss: 3.0348
# Epoch 13/50
# 615/615 [==============================] - 32s 51ms/step - loss: 2.7609 - val_loss: 3.0137
# Epoch 14/50
# 615/615 [==============================] - 32s 51ms/step - loss: 2.7155 - val_loss: 2.9927
# Epoch 15/50
# 615/615 [==============================] - 32s 51ms/step - loss: 2.6739 - val_loss: 2.9798
# Epoch 16/50
# 615/615 [==============================] - 32s 51ms/step - loss: 2.6359 - val_loss: 2.9644
# Epoch 17/50
# 615/615 [==============================] - 31s 51ms/step - loss: 2.6015 - val_loss: 2.9600
# Epoch 18/50
# 615/615 [==============================] - 32s 51ms/step - loss: 2.5700 - val_loss: 2.9476
# Epoch 19/50
# 615/615 [==============================] - 32s 51ms/step - loss: 2.5353 - val_loss: 2.9354
# Epoch 20/50
# 615/615 [==============================] - 32s 52ms/step - loss: 2.5035 - val_loss: 2.9350
# Epoch 21/50
# 615/615 [==============================] - 32s 52ms/step - loss: 2.4805 - val_loss: 2.9263
# Epoch 22/50
# 615/615 [==============================] - 32s 51ms/step - loss: 2.4517 - val_loss: 2.9155
# Epoch 23/50
# 615/615 [==============================] - 32s 51ms/step - loss: 2.4241 - val_loss: 2.9169
# Epoch 24/50
# 615/615 [==============================] - 32s 52ms/step - loss: 2.3987 - val_loss: 2.9114
# Epoch 25/50
# 615/615 [==============================] - 32s 51ms/step - loss: 2.3804 - val_loss: 2.9108
# Epoch 26/50
# 615/615 [==============================] - 32s 51ms/step - loss: 2.3605 - val_loss: 2.9086
# Epoch 27/50
# 615/615 [==============================] - 32s 51ms/step - loss: 2.3378 - val_loss: 2.9052
# Epoch 28/50
# 615/615 [==============================] - 32s 51ms/step - loss: 2.3161 - val_loss: 2.8972
# Epoch 29/50
# 615/615 [==============================] - 32s 51ms/step - loss: 2.2969 - val_loss: 2.9174
# Epoch 30/50
# 615/615 [==============================] - 32s 51ms/step - loss: 2.2810 - val_loss: 2.8951
# Epoch 31/50
# 615/615 [==============================] - 32s 51ms/step - loss: 2.2650 - val_loss: 2.8972
# Epoch 32/50
# 615/615 [==============================] - 32s 51ms/step - loss: 2.2491 - val_loss: 2.8942
# Epoch 33/50
# 615/615 [==============================] - 32s 51ms/step - loss: 2.2341 - val_loss: 2.8942
# Epoch 34/50
# 615/615 [==============================] - 32s 51ms/step - loss: 2.2199 - val_loss: 2.8942
# Epoch 35/50
# 615/615 [==============================] - 32s 51ms/step - loss: 2.2058 - val_loss: 2.8973
# Epoch 36/50
# 615/615 [==============================] - 32s 51ms/step - loss: 2.1952 - val_loss: 2.8926
# Epoch 37/50
# 615/615 [==============================] - 32s 51ms/step - loss: 2.1841 - val_loss: 2.9000
# Epoch 38/50
# 615/615 [==============================] - 32s 51ms/step - loss: 2.1701 - val_loss: 2.8957
# Epoch 38: early stopping

# %%
# 훈련 데이터의 손실과 검증 데이터의 손실이 줄어드는 과정을 시각화
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
# 필요한 3개의 사전을 아래와 같이 미리 준비
src_index_to_word = src_tokenizer.index_word # 원문 단어 집합에서 정수 -> 단어를 얻음
tar_word_to_index = tar_tokenizer.word_index # 요약 단어 집합에서 단어 -> 정수를 얻음
tar_index_to_word = tar_tokenizer.index_word # 요약 단어 집합에서 정수 -> 단어를 얻음

print('=3')
# Out:
# =3

# %%
# 인퍼런스 인코더 설계
encoder_model = Model(inputs=encoder_inputs, outputs=[encoder_outputs, state_h, state_c])

# 이전 시점의 상태들을 저장하는 텐서
decoder_state_input_h = Input(shape=(hidden_size,))
decoder_state_input_c = Input(shape=(hidden_size,))

dec_emb2 = dec_emb_layer(decoder_inputs)

# 문장의 다음 단어를 예측하기 위해서 초기 상태(initial_state)를 이전 시점의 상태로 사용. 이는 뒤의 함수 decode_sequence()에 구현
# 훈련 과정에서와 달리 LSTM의 리턴하는 은닉 상태와 셀 상태인 state_h와 state_c를 버리지 않음.
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

print('=3')
# Out:
# =3

# %%
# 어텐션 함수
decoder_hidden_state_input = Input(shape=(text_max_len, hidden_size))
attn_out_inf = attn_layer([decoder_outputs2, decoder_hidden_state_input])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# 인퍼런스 디코더의 출력층
decoder_outputs2 = decoder_softmax_layer(decoder_inf_concat) 

# 최종 디코더 모델
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

print('=3')
# Out:
# =3

# %%
# 인퍼런스 단계에서 단어 시퀀스를 완성하는 함수를 만들기
def decode_sequence(input_seq):
    # 입력으로부터 인코더의 상태를 얻음
    e_out, e_h, e_c = encoder_model.predict(input_seq)

     # <SOS>에 해당하는 토큰 생성
    target_seq = np.zeros((1,1))
    target_seq[0, 0] = tar_word_to_index['sostoken']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition: # stop_condition이 True가 될 때까지 루프 반복

        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = tar_index_to_word[sampled_token_index]

        if (sampled_token!='eostoken'):
            decoded_sentence += ' '+sampled_token

        #  <eos>에 도달하거나 최대 길이를 넘으면 중단.
        if (sampled_token == 'eostoken'  or len(decoded_sentence.split()) >= (headlines_max_len-1)):
            stop_condition = True

        # 길이가 1인 타겟 시퀀스를 업데이트
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # 상태를 업데이트 합니다.
        e_h, e_c = h, c

    return decoded_sentence
print('=3')
# Out:
# =3

# %%
# 원문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2text(input_seq):
    temp=''
    for i in input_seq:
        if (i!=0):
            temp = temp + src_index_to_word[i]+' '
    return temp

# 요약문의 정수 시퀀스를 텍스트 시퀀스로 변환
def seq2summary(input_seq):
    temp=''
    for i in input_seq:
        if ((i!=0 and i!=tar_word_to_index['sostoken']) and i!=tar_word_to_index['eostoken']):
            temp = temp + tar_index_to_word[i] + ' '
    return temp

print('=3')
# Out:
# =3

# %%
# 테스트 데이터 약 50개의 샘플에 대해서 실제 요약과 예측된 요약을 비교
for i in range(50, 100):
    print("원문 :", seq2text(encoder_input_test[i]))
    print("실제 요약 :", seq2summary(decoder_input_test[i]))
    print("예측 요약 :", decode_sequence(encoder_input_test[i].reshape(1, text_max_len)))
    print("\n")
# Out:
# 원문 : supreme court judges asked chief justice india dipak misra impeached said nation decide judges also released two month old letter cji criticising selective important cases judges letter also stated mentioning details avoid embarrassing judiciary
# 실제 요약 : let the nation decide if cji should be impeached sc judges
# 예측 요약 :  sc judges of the nation one of the country sc
#
#
# 원문 : munna bajrangi gangster uttar pradesh undergoing trial murder bjp leader rai bajrangi core member five time mla mukhtar ansari gang around cases murder extortion wife recently alleged police planning kill fake encounter
# 실제 요약 : who was munna the gangster shot dead in up jail
# 예측 요약 :  bjp leader accused of raping yr old in up
#
#
# 원문 : commenting supreme court verdict declaring triple talaq unconstitutional aimim president asaduddin owaisi said respect judgement however added going great task implement ground notably earlier year owaisi called muslims stand support triple talaq like jallikattu
# 실제 요약 : we have to respect judgement aimim chief on triple talaq
# 예측 요약 :  triple talaq is not owaisi on sc verdict
#
#
# 원문 : patidar leader hardik patel indefinite fast since august press reservation community admitted hospital friday health deteriorated hospital gave glucose stated vital parameters normal meanwhile janata dal leader sharad yadav dmk leader raja visited
# 실제 요약 : hardik patel admitted to hospital amid indefinite fast
# 예측 요약 :  hardik patel day fast with aiims hardik patel
#
#
# 원문 : believed modern christmas tree originated germany th century tree brought england germany prince albert went marry queen victoria tree became christmas tradition masses london newspaper published photo royal tree eight years later
# 실제 요약 : how did the tradition of the christmas tree
# 예측 요약 :  th century celebrates th century with th century
#
#
# 원문 : responding criticism episode american tv show quantico showed indian terrorists framing pakistan trying blow manhattan new york priyanka chopra tweeted proud indian never change extremely saddened sorry sentiments hurt would never intention added
# 실제 요약 : priyanka apologises as shows indians as terrorists
# 예측 요약 :  tv show pak actress slams priyanka over remark
#
#
# 원문 : chess player banned iranian national women team wearing hijab international competition reportedly joined us team refused wear hijab competition february competition brother also chess player competed israeli banned
# 실제 요약 : iran chess player banned for not wearing hijab joins us team
# 예측 요약 :  women banned from men for wearing dress ban
#
#
# 원문 : doctored image argentina football captain lionel messi wherein seen crying blood released propaganda cell terror group isis threat fifa world cup russia fighting state failure dictionary read message accompanying image messi behind bars
# 실제 요약 : isis poster threatening wc shows messi crying blood
# 예측 요약 :  messi reveals he releases his kids from fifa wc
#
#
# 원문 : aditi rao hydari said kind backing bollywood never adding came nowhere added feels blessed many people made part vision aditi said getting work tough work people always wanted difficult
# 실제 요약 : do not have backing but never about it aditi rao
# 예측 요약 :  never never an actor to be never an actor
#
#
# 원문 : karnataka state road transport corporation decided establish indira canteens bus stands major cities district headquarters transport minister said monday locations canteens identified basis number commuters government run indira canteens started august provide food subsidised rates
# 실제 요약 : govt bus stands in karnataka to get indira canteens
# 예측 요약 :  karnataka govt to start own own vehicles
#
#
# 원문 : union minister arjun ram meghwal said gst new bride country brought law country grows right direction added responding comment much clarity gst also said real estate industry communicate government issues related gst
# 실제 요약 : gst new bride for the country union minister
# 예측 요약 :  gst is not the government in the law minister
#
#
# 원문 : year old woman allegedly committed suicide hanging ceiling fan strangled mentally challenged seven year old twin sons death maharashtra thane saturday woman left behind note saying depressed several years unable cope condition sons police said
# 실제 요약 : woman commits suicide after killing mentally challenged sons
# 예측 요약 :  woman commits suicide after family suicide her
#
#
# 원문 : promising minimum income guarantee every poor person congress president rahul gandhi tuesday said voted power congress pass women reservation bill want see women positions leadership added bill seeks reservation seats women lok sabha legislative assemblies
# 실제 요약 : will pass women reservation bill if voted to power rahul
# 예측 요약 :  women jobs in poor education rahul gandhi
#
#
# 원문 : actress richa chadha confirmed contracted virus also known swine flu fell sick almost immediately upon return us move around little added however richa said plans attend trailer launch event upcoming film fukrey returns taking necessary
# 실제 요약 : actress richa chadha contracts swine flu
# 예측 요약 :  richa chadha returns home harvey returns to return to month
#
#
# 원문 : india saturday signed nine iran talks held pm narendra modi iranian president hassan rouhani ministry external affairs said leaders held discussions cooperation trade investment connectivity security among issues pm modi said president rouhani visit showed two nations wish deeper cooperation key areas
# 실제 요약 : india iran sign agreements during bilateral talks
# 예측 요약 :  india iran sign iran supreme court to
#
#
# 원문 : lockheed martin announced tuesday producing wings fighter jets india us defence giant partner tata advanced systems limited manufacture wings hyderabad facility move aimed selection indian air force would boost make india initiative said lockheed
# 실제 요약 : to make fighter jet wings in india with tata
# 예측 요약 :  tcs to buy us to make india debut with firm
#
#
# 원문 : delhi police tuesday arrested jnu professor atul johri allegations sexual harassment several students students alleged accused openly demanded sex made sexually coloured remarks held students objected comes days protests jnu students accused police shielding accused
# 실제 요약 : jnu professor arrested for sexual harassment after protests
# 예측 요약 :  college students booked for sexual harassment in delhi
#
#
# 원문 : freida pinto manoj bajpayee anupam kher rajkummar rao starrer love sonia screened united nations headquarters new york screened occasion international day girl child october film revolves around human trafficking also stars thakur moore released september india
# 실제 요약 : freida love sonia to be screened at united nations
# 예측 요약 :  john rao to produce film on this year
#
#
# 원문 : german bus service startup started testing vr headsets passengers certain routes us headsets created interactive virtual reality games riders play bus journey testing expected last three months time
# 실제 요약 : german bus service startup testing vr on riders
# 예측 요약 :  bus service to be part of in bus service
#
#
# 원문 : china helping pakistan build permanent bunkers along border gujarat rajasthan according india today report around bunkers already built added china recently acknowledged pakistan priority neighbourhood diplomacy pledged lend support core interests region
# 실제 요약 : china helping pak build bunkers along india border report
# 예측 요약 :  china to build pakistan to pakistan
#
#
# 원문 : supreme court appointed committee administrators asked bcci select indian cricket team icc champions trophy begins june deadline selection april bcci announce squad protest icc decision implement new financial model would result revenue loss bcci
# 실제 요약 : select indian team for champions trophy coa orders bcci
# 예측 요약 :  bcci appointed as new coach of bcci staff
#
#
# 원문 : google new us campus first built google scratch allow people inside building without approval let access retail stores made google employees scheduled completed acre campus includes two storey building glass walls canopy like roof solar panel tiles
# 실제 요약 : google new us campus to keep stores open to public
# 예측 요약 :  google first to build live in us
#
#
# 원문 : cab hailing startup uber board tuesday voted favour investment deal softbank approved series governance changes limit co founder travis kalanick power uber changes strengthen uber independence ensure equality among shareholders uber said uber board decided expand size board directors
# 실제 요약 : uber to with softbank deal to limit travis power
# 예측 요약 :  uber appoints its own snapdeal board as ceo
#
#
# 원문 : year old woman arrested allegedly murdering year old brother always telling mother speaking boyfriend phone accused smashed brother head hammer slit throat knife reports said earlier blamed murder father later confessed interrogation
# 실제 요약 : yr old kills brother for telling mom about her boyfriend
# 예측 요약 :  woman kills yr old for trying to kill her mother
#
#
# 원문 : canada based researchers developed augmented reality system projects patients internal directly body away need make called technology uses infrared cameras body project images tracking body movement doctors choose see lungs blood vessels depending case
# 실제 요약 : system lets doctors see under patients skin without cutting
# 예측 요약 :  ai can detect cancer with body made
#
#
# 원문 : pm narendra modi claimed facing electricity drinking water problems speech poll bound telangana cm chandrashekar rao said lie sake votes guts tell people truth fly right debate proven wrong added
# 실제 요약 : do not lie for votes kcr to pm modi over his speech in telangana
# 예측 요약 :  pm modi should have been given vote but did not have modi
#
#
# 원문 : security personnel killed taliban attack military base afghanistan monday official afghanistan defence ministry said attackers rammed captured military packed explosives national directorate security training centre maidan province two gunmen also entered campus opened fire shot
# 실제 요약 : taliban attack on afghan security base kills over
# 예측 요약 :  taliban attack afghan afghan afghanistan kills
#
#
# 원문 : donald trump administration recently unveiled largest tax reform history united states proposes cut corporate tax rates plan would three individual income tax instead current seven also proposes abolish alternative minimum tax place since
# 실제 요약 : trump administration proposes largest tax reform
# 예측 요약 :  trump tax income tax to be cut off in us
#
#
# 원문 : poster shahid kapoor shraddha kapoor starrer batti gul meter chalu unveiled film social drama reportedly deals problem power shortage india film directed shree narayan singh earlier directed toilet ek prem katha scheduled release september
# 실제 요약 : poster of shahid shraddha batti gul meter chalu unveiled
# 예측 요약 :  shahid kapoor starrer gul hits the theatres
#
#
# 원문 : indian rounder hardik pandya expressed surprise instagram photo indian squash player dipika seen spending time private pool caribbean accompanying husband dinesh karthik caribbean later responded private pool villa come serve also
# 실제 요약 : hardik pandya surprised by dipika private pool
# 예측 요약 :  pandya pandya meets karthik after she down her
#
#
# 원문 : indore municipal corporation tabled proposal rename city indore madhya pradesh bjp corporator demanded change sudhir asked furnish historic documents support claim chairman ajay singh said city named ancient temple claimed
# 실제 요약 : civic body proposal to rename indore as
# 예측 요약 :  himachal pradesh to get legal status to
#
#
# 원문 : delhi daredevils wicketkeeper batsman rishabh pant smashed sunrisers hyderabad thursday record highest ever score indian history indian premier league pant overtook chennai super kings murali vijay slammed rajasthan royals year old among indian players score century ipl
# 실제 요약 : rishabh pant highest ever score by an indian in ipl
# 예측 요약 :  pant highest ever rishabh pant breaks away in
#
#
# 원문 : least clinics pharmacies sealed last days jammu kashmir nine teachers one public health employee another government employee caught treating patients running illegal pharmacies regional medical officer said six seven people among even passed high school officer added
# 실제 요약 : fake doctors found treating patients in clinics shut
# 예측 요약 :  inmates suspended for not paying for civil services
#
#
# 원문 : washington among nominees best actor leading role category oscars roman israel received nomination call name daniel day lewis nominated phantom thread nominees include daniel get gary darkest hour
# 실제 요약 : who are the for best actor at oscars
# 예측 요약 :  named best actor at oscars
#
#
# 원문 : information broadcasting minister smriti irani monday said public broadcaster doordarshan create quality content improve revenue generation advertisements ease burden taxpayers also stressed need develop regional language content doordarshan better effective communication people parts country
# 실제 요약 : improve doordarshan content get more ads smriti irani
# 예측 요약 :  smriti irani most important irani
#
#
# 원문 : broke two male passengers aboard recent southwest airlines plane landed california one man reportedly suffered minor injuries could continue destination man detained gate arrested airlines thanked employees preventing incident getting worse
# 실제 요약 : passengers get into aboard plane
# 예측 요약 :  man crashes in plane flyers flyers during flight
#
#
# 원문 : release date upcoming richa chadha ali fazal starrer fukrey returns postponed december sequel film fukrey film also stars pulkit samrat varun sharma singh directed singh lamba film earlier scheduled release december
# 실제 요약 : release date of richa ali fazal fukrey returns postponed
# 예측 요약 :  release date of ali fazal veere di wedding
#
#
# 원문 : kangana ranaut said thick skinned person reference alleged jibe vidya balan kangana recent additional writer credit controversy simran poster vidya balan recently shared picture holding additional credit card captioned needs credit director gifts simran main writer apurva asrani also vidya picture
# 실제 요약 : am kangana on vidya alleged credit jibe
# 예측 요약 :  kangana ranaut had rani kharagpur kangana ranaut
#
#
# 원문 : iit madras opened two separate besides setting separate utensils wash students vegetarian non vegetarian food campus mess started demand pure vegetarian mess become full fledged iit madras trying become world class institute culture still regressive student body posted facebook
# 실제 요약 : separate mess for veg non veg iit students sparks row
# 예측 요약 :  iit bombay hc allows non non veg non
#
#
# 원문 : dig congress leader chidambaram recent remark kashmir union minister mukhtar abbas naqvi tuesday accused congress speaking language separatists state kashmir problem congress legacy nurtured problem two faces coin added
# 실제 요약 : congress speaking language of separatists union minister
# 예측 요약 :  congress should be called chidambaram
#
#
# 원문 : indian railways changed category name forms offered people special needs february new forms word blind replaced persons visual impairment total absence sight deaf dumb changed persons hearing speech impairment
# 실제 요약 : railways replaces with in forms
# 예측 요약 :  railways to give people to name
#
#
# 원문 : actor featured film franchise fast furious apologised instagram sexist remarks earlier interview apology also mentioned ladies deserve better interview said aggressive women never without man standards
# 실제 요약 : fast and furious actor apologises for sexist remarks
# 예측 요약 :  apologises for remark on my apologises for
#
#
# 원문 : official statement kauvery hospital dmk president karunanidhi admitted icu stated setback clinical condition year old leader statement added active medical support vital signs reports suggested karunanidhi health became critical pulse rate dropped sharply sunday
# 실제 요약 : in karunanidhi health signs
# 예측 요약 :  karunanidhi karunanidhi health dmk chief
#
#
# 원문 : chinese automaker filed complaint country trademark regulator mercedes benz use brand green energy vehicles claims used name two door battery electric car two years china key market mercedes electric cars sold china rest world combined
# 실제 요약 : chinese company files trademark complaint against mercedes
# 예측 요약 :  china firm makes cars to make tesla car in china
#
#
# 원문 : seven indian companies made latest carbon clean list features world largest publicly traded companies making significant revenue clean energy top three indian companies energy bharat heavy tata chemicals notably germany japan us greater china larger representation india list
# 실제 요약 : seven indian firms among world top green energy firms
# 예측 요약 :  india to shut down largest world largest energy study
#
#
# 원문 : hyderabad task force police arrested three people allegedly cloning fingerprints faculty members various educational institutions could falsely mark attendance biometric attendance system cloning technique learned via internet cloned fingerprint priced eighty cloned fingerprints biometric machine seized
# 실제 요약 : college faculty to fake attendance held
# 예측 요약 :  luru university held for making students arrest
#
#
# 원문 : us based ai startup systems hired former intel executive vice president engineering business development lead engineering team continue expansion innovation needed disrupt marketplace startup said prior served vp architecture cto intel data center group
# 실제 요약 : ai startup hires former intel executive as vp of engineering
# 예측 요약 :  ola appoints ex vp and as ceo
#
#
# 원문 : india world champion yadav succumbed injuries following road accident delhi haryana border today yadav sustained head injuries severe internal bleeding due accident earlier claimed lives four yadav last world championship gold among six athletes travelling delhi panipat
# 실제 요약 : indian world champion dies following car crash
# 예측 요약 :  india pilot killed in road accident in delhi
#
#
# 원문 : south africa anti apartheid activist mandela passed away monday prolonged illness age family said statement former wife south africa president nelson mandela campaigned rights black south africans former husband release year imprisonment fight apartheid
# 실제 요약 : mandela ex wife anti activist dies at
# 예측 요약 :  south africa admits to be found dead after wife death
#
#
# 원문 : sunny deol sakshi tanwar mohalla released friday fails make impact script wrote bollywood hungama according ndtv mohalla majorly flawed uneven film collection scenes said indian express rated bollywood hungama indian express ndtv
# 실제 요약 : sunny deol sakshi hits the theatres
# 예측 요약 :  sunny deol starrer hits the theatres

# %% [markdown]
# ###  Summa을 이용해서 추출적 요약

# %%
# !pip install summa
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: summa in /usr/local/lib/python3.7/dist-packages (1.2.0)
# Requirement already satisfied: scipy>=0.19 in /usr/local/lib/python3.7/dist-packages (from summa) (1.7.3)
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in /usr/local/lib/python3.7/dist-packages (from scipy>=0.19->summa) (1.21.6)

# %%
import requests
from summa.summarizer import summarize

# %%
# 데이터 불러오기
data = pd.read_csv('/content/drive/MyDrive/AIFFEL/EX/E12/news_summarization/data/news_summary_more.csv')

# %%
text = data['text']
text[0]
# Out:
# "Saurav Kant, an alumnus of upGrad and IIIT-B's PG Program in Machine learning and Artificial Intelligence, was a Sr Systems Engineer at Infosys with almost 5 years of work experience. The program and upGrad's 360-degree career support helped him transition to a Data Scientist at Tech Mahindra with 90% salary hike. upGrad's Online Power Learning has powered 3 lakh+ careers."

# %%
print('Headlines:')
print(summarize(text[0], words=5))
# Out:
# Headlines:
# upGrad's Online Power Learning has powered 3 lakh+ careers.

# %%
# 리스트로 출력결과 받기
print('Headlines:')
print(summarize(text[0], ratio=0.4, split=True))
# Out:
# Headlines:
# ["upGrad's Online Power Learning has powered 3 lakh+ careers."]

# %%
# 요약 함수
headlines = []
for i in range(len(text)):
    headline = summarize(text[i], ratio=0.4)
    headlines.append(headline)

# %%
for i in range(10):
    print("원문 :", data['text'][i])
    print("실제 헤드라인 :", data['headlines'][i])
    print("예측 헤드라인 :", headlines[i])
    print("\n")
# Out:
# 원문 : Saurav Kant, an alumnus of upGrad and IIIT-B's PG Program in Machine learning and Artificial Intelligence, was a Sr Systems Engineer at Infosys with almost 5 years of work experience. The program and upGrad's 360-degree career support helped him transition to a Data Scientist at Tech Mahindra with 90% salary hike. upGrad's Online Power Learning has powered 3 lakh+ careers.
# 실제 헤드라인 : upGrad learner switches to career in ML & Al with 90% salary hike
# 예측 헤드라인 : upGrad's Online Power Learning has powered 3 lakh+ careers.
#
#
# 원문 : Kunal Shah's credit card bill payment platform, CRED, gave users a chance to win free food from Swiggy for one year. Pranav Kaushik, a Delhi techie, bagged this reward after spending 2000 CRED coins. Users get one CRED coin per rupee of bill paid, which can be used to avail rewards from brands like Ixigo, BookMyShow, UberEats, Cult.Fit and more.
# 실제 헤드라인 : Delhi techie wins free food from Swiggy for one year on CRED
# 예측 헤드라인 : Users get one CRED coin per rupee of bill paid, which can be used to avail rewards from brands like Ixigo, BookMyShow, UberEats, Cult.Fit and more.
#
#
# 원문 : New Zealand defeated India by 8 wickets in the fourth ODI at Hamilton on Thursday to win their first match of the five-match ODI series. India lost an international match under Rohit Sharma's captaincy after 12 consecutive victories dating back to March 2018. The match witnessed India getting all out for 92, their seventh lowest total in ODI cricket history.
# 실제 헤드라인 : New Zealand end Rohit Sharma-led India's 12-match winning streak
# 예측 헤드라인 : The match witnessed India getting all out for 92, their seventh lowest total in ODI cricket history.
#
#
# 원문 : With Aegon Life iTerm Insurance plan, customers can enjoy tax benefits on your premiums paid and save up to â¹46,800^ on taxes. The plan provides life cover up to the age of 100 years. Also, customers have options to insure against Critical Illnesses, Disability and Accidental Death Benefit Rider with a life cover up to the age of 80 years.
# 실제 헤드라인 : Aegon life iTerm insurance plan helps customers save tax
# 예측 헤드라인 : Also, customers have options to insure against Critical Illnesses, Disability and Accidental Death Benefit Rider with a life cover up to the age of 80 years.
#
#
# 원문 : Speaking about the sexual harassment allegations against Rajkumar Hirani, Sonam Kapoor said, "I've known Hirani for many years...What if it's not true, the [#MeToo] movement will get derailed." "In the #MeToo movement, I always believe a woman. But in this case, we need to reserve our judgment," she added. Hirani has been accused by an assistant who worked in 'Sanju'.
# 실제 헤드라인 : Have known Hirani for yrs, what if MeToo claims are not true: Sonam
# 예측 헤드라인 : Speaking about the sexual harassment allegations against Rajkumar Hirani, Sonam Kapoor said, "I've known Hirani for many years...What if it's not true, the [#MeToo] movement will get derailed." "In the #MeToo movement, I always believe a woman.
#
#
# 원문 : Pakistani singer Rahat Fateh Ali Khan has denied receiving any notice from the Enforcement Directorate over allegedly smuggling foreign currency out of India. "It would have been better if the authorities would have served the notice first if any and then publicised this," reads a press release issued on behalf of Rahat. The statement further called the allegation "bizarre".
# 실제 헤드라인 : Rahat Fateh Ali Khan denies getting notice for smuggling currency
# 예측 헤드라인 : Pakistani singer Rahat Fateh Ali Khan has denied receiving any notice from the Enforcement Directorate over allegedly smuggling foreign currency out of India.
#
#
# 원문 : India recorded their lowest ODI total in New Zealand after getting all out for 92 runs in 30.5 overs in the fourth ODI at Hamilton on Thursday. Seven of India's batsmen were dismissed for single-digit scores, while their number ten batsman Yuzvendra Chahal top-scored with 18*(37). India's previous lowest ODI total in New Zealand was 108.
# 실제 헤드라인 : India get all out for 92, their lowest ODI total in New Zealand
# 예측 헤드라인 : India's previous lowest ODI total in New Zealand was 108.
#
#
# 원문 : Weeks after ex-CBI Director Alok Verma told the Department of Personnel and Training to consider him retired, the Home Ministry asked him to join work on the last day of his fixed tenure as Director on Thursday. The ministry directed him to immediately join as DG, Fire Services, the post he was transferred to after his removal as CBI chief.
# 실제 헤드라인 : Govt directs Alok Verma to join work 1 day before his retirement
# 예측 헤드라인 :
#
#
# 원문 : Andhra Pradesh CM N Chandrababu Naidu has said, "When I met then US President Bill Clinton, I addressed him as Mr Clinton, not as 'sir'. (PM Narendra) Modi is my junior in politics...I addressed him as sir 10 times." "I did this...to satisfy his ego in the hope that he will do justice to the state," he added.
# 실제 헤드라인 : Called PM Modi 'sir' 10 times to satisfy his ego: Andhra CM
# 예측 헤드라인 :
#
#
# 원문 : Congress candidate Shafia Zubair won the Ramgarh Assembly seat in Rajasthan, by defeating BJP's Sukhwant Singh with a margin of 12,228 votes in the bypoll. With this victory, Congress has taken its total to 100 seats in the 200-member assembly. The election to the Ramgarh seat was delayed due to the death of sitting MLA and BSP candidate Laxman Singh.
# 실제 헤드라인 : Cong wins Ramgarh bypoll in Rajasthan, takes total to 100 seats
# 예측 헤드라인 : Congress candidate Shafia Zubair won the Ramgarh Assembly seat in Rajasthan, by defeating BJP's Sukhwant Singh with a margin of 12,228 votes in the bypoll.

# %% [markdown]
# ## 결과
# ### 추상적 요약
#     실제 요약 : let the nation decide if cji should be impeached sc judges
#
#     예측 요약 :  sc judges of the nation one of the country sc
#
# ------------------------------
#     실제 요약 : who was munna the gangster shot dead in up jail
#
#     예측 요약 :  bjp leader accused of raping yr old in up
#
# -------------------------------------
#     실제 요약 : we have to respect judgement aimim chief on triple talaq
#
#     예측 요약 :  triple talaq is not owaisi on sc verdict
#
# -----------------------------
#     실제 요약 : hardik patel admitted to hospital amid indefinite fast
#
#     예측 요약 :  hardik patel day fast with aiims hardik patel
#
# -----------------------------
#     실제 요약 : how did the tradition of the christmas tree
#
#     예측 요약 :  th century celebrates th century with th century
# - 실제 요약에 들어가 있는 단어가 어느 정도 예측 요약에도 들어가 있는 걸 확인 가능.
# - 문법적으로 맞는지는 잘 모르겠음.
#
# ### 추출적 요약
#     원문 : Saurav Kant, an alumnus of upGrad and IIIT-B's PG Program in Machine learning and Artificial Intelligence, was a Sr Systems Engineer at Infosys with almost 5 years of work experience. The program and upGrad's 360-degree career support helped him transition to a Data Scientist at Tech Mahindra with 90% salary hike. upGrad's Online Power Learning has powered 3 lakh+ careers.
#     실제 헤드라인 : upGrad learner switches to career in ML & Al with 90% salary hike
#     예측 헤드라인 : upGrad's Online Power Learning has powered 3 lakh+ careers.
#
# ------------------------------------
#     원문 : Kunal Shah's credit card bill payment platform, CRED, gave users a chance to win free food from Swiggy for one year. Pranav Kaushik, a Delhi techie, bagged this reward after spending 2000 CRED coins. Users get one CRED coin per rupee of bill paid, which can be used to avail rewards from brands like Ixigo, BookMyShow, UberEats, Cult.Fit and more.
#     실제 헤드라인 : Delhi techie wins free food from Swiggy for one year on CRED
#     예측 헤드라인 : Users get one CRED coin per rupee of bill paid, which can be used to avail rewards from brands like Ixigo, BookMyShow, UberEats, Cult.Fit and more.
#
# --------------------------------------
#     원문 : New Zealand defeated India by 8 wickets in the fourth ODI at Hamilton on Thursday to win their first match of the five-match ODI series. India lost an international match under Rohit Sharma's captaincy after 12 consecutive victories dating back to March 2018. The match witnessed India getting all out for 92, their seventh lowest total in ODI cricket history.
#     실제 헤드라인 : New Zealand end Rohit Sharma-led India's 12-match winning streak
#     예측 헤드라인 : The match witnessed India getting all out for 92, their seventh lowest total in ODI cricket history.
#
# ------------------------------------------
#     원문 : With Aegon Life iTerm Insurance plan, customers can enjoy tax benefits on your premiums paid and save up to â¹46,800^ on taxes. The plan provides life cover up to the age of 100 years. Also, customers have options to insure against Critical Illnesses, Disability and Accidental Death Benefit Rider with a life cover up to the age of 80 years.
#     실제 헤드라인 : Aegon life iTerm insurance plan helps customers save tax
#     예측 헤드라인 : Also, customers have options to insure against Critical Illnesses, Disability and Accidental Death Benefit Rider with a life cover up to the age of 80 years.
#
# -----------------------------------------
#     원문 : Speaking about the sexual harassment allegations against Rajkumar Hirani, Sonam Kapoor said, "I've known Hirani for many years...What if it's not true, the [#MeToo] movement will get derailed." "In the #MeToo movement, I always believe a woman. But in this case, we need to reserve our judgment," she added. Hirani has been accused by an assistant who worked in 'Sanju'.
#     실제 헤드라인 : Have known Hirani for yrs, what if MeToo claims are not true: Sonam
#     예측 헤드라인 : Speaking about the sexual harassment allegations against Rajkumar Hirani, Sonam Kapoor said, "I've known Hirani for many years...What if it's not true, the [#MeToo] movement will get derailed." "In the #MeToo movement, I always believe a woman.
# - 예측 헤드라인이 실제 헤드라인과는 많이 다르지만 원문과 비교하면 원문의 마지막 줄이나 첫번째 줄을 사용한 걸 확인 할 수 있다.
# - 원문에 있는 문장을 가져왔기 때문에 문법은 맞는 듯 함.

# %% [markdown]
# ## 회고
# - 코드는 노드에서 했던 코드를 그대로 사용해서 딱히 어려운 부분은 없었음
# - 처음엔 batch size = 256으로 돌림 -> Loss : 2.1406, val_Loss : 2.9345
# - 그 다음 batch size = 516으로 돌림 -> Loss : 2.1835, val_Loss : 2.9653
# - Loss 값들이 올라감
# - batch size = 128로 시도 -> Loss : 2.1701, val_loss : 2.8957
# - Loss 값 내려감
# - 요약 결과에 차이는 별로 못 느끼겠음
